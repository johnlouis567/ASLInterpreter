# %% [markdown]
# # Import and Install General Dependencies

# %%
# !pip3 install mediapipe==0.10.9
# Out:
# Requirement already satisfied: mediapipe==0.10.9 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (0.10.9)
# Requirement already satisfied: absl-py in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from mediapipe==0.10.9) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from mediapipe==0.10.9) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from mediapipe==0.10.9) (24.3.25)
# Requirement already satisfied: matplotlib in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from mediapipe==0.10.9) (3.8.4)
# Requirement already satisfied: numpy in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from mediapipe==0.10.9) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from mediapipe==0.10.9) (4.9.0.80)
# Requirement already satisfied: protobuf<4,>=3.11 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from mediapipe==0.10.9) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from mediapipe==0.10.9) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sounddevice>=0.4.4->mediapipe==0.10.9) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (24.0)
# Requirement already satisfied: pillow>=8 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (2.9.0.post0)
# Requirement already satisfied: pycparser in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.9) (2.21)
# Requirement already satisfied: six>=1.5 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.9) (1.16.0)

# %%
# !pip install tensorflow opencv-python scikit-learn matplotlib
# Out:
# Requirement already satisfied: tensorflow in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (2.16.1)
# Requirement already satisfied: opencv-python in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (4.9.0.80)
# Requirement already satisfied: scikit-learn in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: matplotlib in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (3.8.4)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: six>=1.12.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (3.3.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/john/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)

# %%
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.1 MB/s eta 0:00:001.4 MB/s eta 0:00:01
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import sys

# %% [markdown]
# # Get Videos from Microsoft Dataset

# %%
import json
import pandas as pd

# %%
# Load JSON at the given filepath
def load_data(filepath):
    with open(filepath, 'r') as file:
        return json.load(file)

# %%
# Load the train, test, and validation json files
train_data = load_data('Microsoft-ASL-dataset/MSASL_train.json')
test_data = load_data('Microsoft-ASL-dataset/MSASL_test.json')
val_data = load_data('Microsoft-ASL-dataset/MSASL_val.json')

# %%
# Convert to DataFrame for easier manipulation
train_df = pd.DataFrame(train_data)
test_df = pd.DataFrame(test_data)
val_df = pd.DataFrame(val_data)

# %% [markdown]
# # Download Videos from Microsoft Dataset

# %%
from pytube import YouTube, exceptions
import time
import shutil

# %%
def check_disk_space(directory, required_bytes):
    total, used, free = shutil.disk_usage(directory)
    return free > required_bytes

# %%
def download_video(url, data_path):
    # Ensure that the directory I will be saving the video to exists
    directory = f'{data_path}/Videos'
    if not os.path.exists(directory):
        print(f"Error: The directory {directory} does not exist.")
        sys.exit(1)

    try:
        yt = YouTube(url)
        stream = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first()
        
        # Estimate file size (in bytes)
        file_size = stream.filesize
        if not check_disk_space(directory, file_size):
            print(f"Not enough disk space to download video: {file_size} bytes needed.")
            return 0
            
        video_id = yt.video_id
        video_path = stream.download(output_path=directory, filename=f'{video_id}.mp4')
        
        return video_path
    except exceptions.VideoUnavailable:
        print(f"Video {url} for {action} is unavailable.")
        return None

# %%
# Define the all recognizable actions
DATA_PATH = os.path.join('MicrosoftData')
actions = []
train_action_freq_map = {}
test_action_freq_map = {}
unique_urls = set()
num_train_vids, num_test_vids = 0, 0

# Get all actions and the frequency of those actions in the training set
for i, row in train_df.iterrows():
    if row['label'] < 100:        
        if row['url'] not in unique_urls:
            num_train_vids += 1
            unique_urls.add(row['url'])
            
        # Check if we have seen the action before. If not add it to actions list
        if row['text'] not in train_action_freq_map:
            train_action_freq_map[row['text']] = 1
            actions.append(row['text'])
        else:
            train_action_freq_map[row['text']] += 1
unique_urls.clear()

# Add the frequencies in the testing set
for i, row in test_df.iterrows():
    if row['label'] < 100:
        if row['url'] not in unique_urls:
            num_test_vids += 1
            unique_urls.add(row['url'])
            
        if row['text'] not in test_action_freq_map:
            test_action_freq_map[row['text']] = 1
        else:
            test_action_freq_map[row['text']] += 1
unique_urls.clear()

num_train_data, num_test_data = sum(train_action_freq_map.values()), sum(test_action_freq_map.values())

# %%
print(sum(unavailable_videos.values()))
print()
print(max(unavailable_videos.values()))
# Out:
# 486
# 10

# %%
# Create a directory structure
# Make directory to hold all the videos, train, and test data
os.makedirs(os.path.join(DATA_PATH, 'Videos'), exist_ok=True)
train_dir = os.path.join(DATA_PATH, 'Train')
test_dir = os.path.join(DATA_PATH, 'Test')
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Make directories that will hold all the extracted key points
for action in actions:
#    # Make all of the training dirs
#    for i in range(train_action_freq_map[action]):
#        try:
#            os.makedirs(os.path.join(train_dir, action, str(i)))
#        except:
#            pass
    # Make all of the testing dirs
    for i in range(test_action_freq_map[action]):
        try:
            os.makedirs(os.path.join(test_dir, action, str(i)))
        except:
            pass

# %%
# Download all unique videos
unavailable_videos = {action:0 for action in actions}
unique_urls = set()
urls_skipped_for_space = []

# Download the training data videos
dowload_start_time = time.time()
print('Downloading Training Videos------------------------------------------------------------------------------------------------------------------------')
c = 0
for i, row in train_df.iterrows():
    if row['label'] < 100 and row['url'] not in unique_urls:
        c += 1
        print(f'Downloading Training Video {c}/{num_train_vids}')
        unique_urls.add(row['url'])
        result = download_video(row['url'], DATA_PATH)
        if result is None:
            unavailable_videos[row['text']] += 1
        elif result == 0:
            urls_skipped_for_space.append(row['url'])
            
print('Finished Downloading Training Videos---------------------------------------------------------------------------------------------------------------------')
train_download_end_time = time.time()

# Download the testing data videos
print('Downloading Testing Videos------------------------------------------------------------------------------------------------------------------------')
c = 0
for i, row in test_df.iterrows():
    if row['label'] < 100 and row['url'] not in unique_urls:
        c += 1
        print(f'Downloading Testing Video for {action} ({c}/{num_test_vids})')
        unique_urls.add(row['url'])
        result = download_video(row['url'], DATA_PATH)
        if result is None:
            unavailable_videos[row['text']] += 1
        elif result == 0:
            urls_skipped_for_space.append(row['url'])
print('Finished Downloading Testing Videos------------------------------------------------------------------------------------------------------------------------')
download_end_time = time.time()
print(f'Unavailable videos: {unavailable_videos}')
print(f'Skipped these {len(urls_skipped_for_space)} Videos for space: {urls_skipped_for_space}')
total_time = download_end_time - dowload_start_time
print(f'Total time: {total_time}')
# Out:
# Downloading Training Videos------------------------------------------------------------------------------------------------------------------------
# Downloading Training Video 1/1141
# Downloading Training Video 2/1141
# Video https://www.youtube.com/watch?v=1AyT77LqJzQ for go is unavailable.
# Downloading Training Video 3/1141
# Downloading Training Video 4/1141
# Video www.youtube.com/watch?v=7y5Ye-2-ZBs for go is unavailable.
# Downloading Training Video 5/1141
# Downloading Training Video 6/1141
# Downloading Training Video 7/1141
# Video https://www.youtube.com/watch?v=0Beq_NIDj2c for go is unavailable.
# Downloading Training Video 8/1141
# Downloading Training Video 9/1141
# Downloading Training Video 10/1141
# Video www.youtube.com/watch?v=AoQAPgEUIAs for go is unavailable.
# Video www.youtube.com/watch?v=X9k65VXITzY for go is unavailable.
# Downloading Testing Video for go (347/357)
# Downloading Testing Video for go (348/357)
# Video www.youtube.com/watch?v=VoHLEG8FIH4 for go is unavailable.
# Downloading Testing Video for go (349/357)
# Video https://www.youtube.com/watch?v=w6ZfGv4ns64 for go is unavailable.
# Downloading Testing Video for go (350/357)
# Video www.youtube.com/watch?v=mBNbzPNTVqk for go is unavailable.
# Downloading Testing Video for go (351/357)
# Video www.youtube.com/watch?v=nTaaoVc75-k for go is unavailable.
# Downloading Testing Video for go (352/357)
# Downloading Testing Video for go (353/357)
# Video https://www.youtube.com/watch?v=6JlqUMRxHwo for go is unavailable.
# Downloading Testing Video for go (354/357)
# Video www.youtube.com/watch?v=_2YnCKHJy6U for go is unavailable.
# Downloading Testing Video for go (355/357)
# Downloading Testing Video for go (356/357)
# Video www.youtube.com/watch?v=PUeBxtWPPFw for go is unavailable.
# Finished Downloading Testing Videos------------------------------------------------------------------------------------------------------------------------
# Unavailable videos: {'book': 3, 'school': 6, 'bored': 8, 'like': 2, 'france': 5, 'day': 4, 'happy': 3, 'sad': 7, 'want': 9, 'know': 3, 'need': 5, 'how': 4, 'yellow': 6, 'teacher': 4, 'deaf': 7, 'again': 4, 'sick': 4, 'mother': 5, 'father': 4, 'milk': 3, 'eat': 10, 'drink': 6, 'help': 3, 'you': 3, 'hurt': 8, 'hungry': 5, 'tired': 4, 'where': 7, 'play': 8, 'sister': 3, 'brother': 5, 'grandmother': 4, 'grandfather': 4, 'cousin': 2, 'blue': 6, 'hearing': 4, 'english': 6, 'forget': 1, 'fish': 3, 'brown': 7, 'work': 7, 'live': 7, 'black': 6, 'green': 4, 'here': 4, 'orange': 7, 'pink': 7, 'red': 6, 'spring': 3, 'white': 5, 'same': 7, 'dance': 6, 'bird': 9, 'read': 5, 'lost': 5, 'big': 2, 'sorry': 4, 'paper': 6, 'girl': 4, 'understand': 2, 'what': 6, 'who': 5, 'finish': 5, 'hello': 10, 'yes': 4, 'no': 5, 'fine': 5, 'thanks': 7, 'water': 4, 'nothing': 4, 'student': 2, 'computer': 7, 'sign': 3, 'bathroom': 4, 'name': 4, 'friend': 6, 'nice': 8, 'learn': 4, 'please': 6, 'when': 3, 'write': 2, 'table': 4, 'pencil': 2, 'night': 4, 'boy': 3, 'but': 6, 'doctor': 4, 'walk': 7, 'right': 4, 'now': 2, 'sit': 6, 'man': 2, 'family': 4, 'bad': 6, 'good': 5, 'beautiful': 2, 'nurse': 5, 'draw': 8, 'woman': 3, 'go': 4}
# Skipped these 0 Videos for space: []
# Total time: 3632.980171918869

# %%
print(f'There were {sum(unavailable_videos.values())} out of {num_test_vids + num_train_vids} That were unable to be downloaded')
for key, val in unavailable_videos.items():
    if val == 10:
        print(f'Action {key} was unable to access its video {val} times')
# Out:
# There were 486 out of 1498 That were unable to be downloaded
# Action eat was unable to access its video 10 times
# Action hello was unable to access its video 10 times

# %% [markdown]
# # Detect and Extract Key Features

# %%
# Used to detect the features which will be extracted
mp_holistic = mp.solutions.holistic

# %%
# Find key features on the current frame
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # Convert color from BGR->RGB
    image.flags.writeable = False
    results = model.process(image) # Make prediction on the current image/frame
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # Convert color from RGB->BGR
    return results

# %%
# Create an array of features when they are detected
def extract_keypoints(results):
    # If there is no data for the body part in that frame then we want to create an array of zeros of the same size
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
# Experiment function get every single frame in the video
def extract_keypoints_from_video(video_dir, feature_data_file, video_name, start_time, end_time, detection_method):
    video_file = video_dir + '/' + video_name
    cap = cv2.VideoCapture(video_file)
    cap.set(cv2.CAP_PROP_POS_MSEC, start_time * 1000) # Set the start time to the correct millisecond
    frame_name = 0
    
    while cap.isOpened():
        # Read in the next frame
        frame_id = int(round(cap.get(cv2.CAP_PROP_POS_FRAMES)))
        ret, frame = cap.read()
        
        # Check if the frame was successfully read and is smaller than the end frame
        if ret and frame_id <= end_time * cap.get(cv2.CAP_PROP_FPS):
            # Detect our features in the image
            results = mediapipe_detection(frame, detection_method)

            # Save the frame keypoints to its corresponding file
            keypoints = extract_keypoints(results)
            npy_path = os.path.join(feature_data_file, str(frame_name))
            np.save(npy_path, keypoints)
            frame_name += 1
        else:
            break
    cap.release()
    return frames

# %%
# Loop through all of the training and testing data and extract the key points
action_seen = {action:0 for action in actions}
train_dir = os.path.join(DATA_PATH, 'Train')
test_dir = os.path.join(DATA_PATH, 'Test')
video_path = os.path.join(DATA_PATH, 'Videos')
c_train, c_test = 0, 0
video_errors = {}

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    # Extract points for training data
    #print ('Extracting Key points from training data-----------------------------------------------------------------------------------------')
    #for i, row in train_df.iterrows():
    #    if row['label'] < 100:
    #        # Get the path to the video we are transcribing and its key feature destinations
            action = row['text']
            file_num = str(action_seen[action])
            feature_data_file = os.path.join(train_dir, action, file_num)
            
            # Display progress
            c_train += 1
            print(f'Training data {c_train}/{num_train_data}')

            # Get the video name
            yt = YouTube(row['url'])
            video_id = yt.video_id
            video_name = f'{video_id}.mp4'
            
            # Get video start and stop time
            st = row['start_time']
            et = row['end_time']

            if video_name in os.listdir(video_path):
                try:
                    extract_keypoints_from_video(video_path, feature_data_file, video_name, st, et, holistic)
                    action_seen[action] += 1
                except Exception as e:
                    print(f"Error processing {video_name} for Action {action}: {str(e)}")
                    if video_name not in video_errors:
                        video_errors[video_name] = 1
                    else:
                        video_errors[video_name] += 1
                

    # Extract points for test data
    s_time = time.time()
    print ('Extracting Key points from testing data-----------------------------------------------------------------------------------------')
    for i, row in test_df.iterrows():
        if row['label'] < 100:
            # Get the path to the video we are transcribing and its key feature destinations
            action = row['text']
            file_num = str(action_seen[action])
            feature_data_file = os.path.join(test_dir, action, file_num)

            # Display progress
            c_test += 1
            print(f'Testing data {c_test}/{num_test_data}')

            # Get the video name
            yt = YouTube(row['url'])
            video_id = yt.video_id
            video_name = f'{video_id}.mp4'
            
            # Get video start and stop time
            st = row['start_time']
            et = row['end_time']

            if video_name in os.listdir(video_path):
                try:
                    extract_keypoints_from_video(video_path, feature_data_file, video_name, st, et, holistic)
                    action_seen[action] += 1
                except Exception as e:
                    print(f"Error processing {video_name} for Action {action}: {str(e)}")
                    if video_name not in video_errors:
                        video_errors[video_name] = 1
                    else:
                        video_errors[video_name] += 1
    e_time = time.time()
    print(f'Runtime: {e_time-s_time}')
# Out:
# Extracting Key points from testing data-----------------------------------------------------------------------------------------
# Testing data 1/757
# Testing data 2/757
# Testing data 3/757
# Testing data 4/757
# Testing data 5/757
# I0000 00:00:1714535497.240549       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1 Pro
# Testing data 6/757
# Testing data 7/757
# Testing data 8/757
# Testing data 9/757
# Testing data 10/757
# Testing data 11/757
# Testing data 12/757
# Testing data 13/757
# Testing data 14/757
# Testing data 15/757
# Testing data 16/757
# Testing data 17/757
# Testing data 18/757
# Testing data 19/757
# Testing data 20/757
# Testing data 21/757
# Testing data 22/757
# Testing data 23/757
# Testing data 24/757
# Testing data 25/757
# Testing data 26/757
# Testing data 27/757
# Testing data 28/757
# Testing data 29/757
# Testing data 30/757
# Testing data 31/757
# Testing data 32/757
# Testing data 33/757
# Testing data 34/757
# Testing data 35/757
# Testing data 36/757
# Testing data 37/757
# Testing data 38/757
# Testing data 39/757
# Testing data 40/757
# Testing data 41/757
# Testing data 42/757
# Testing data 43/757
# Testing data 44/757
# Testing data 45/757
# Testing data 46/757
# Testing data 47/757
# Testing data 48/757
# Testing data 49/757
# Testing data 50/757
# Testing data 51/757
# Testing data 52/757
# Testing data 53/757
# Testing data 54/757
# Testing data 55/757
# Testing data 56/757
# Testing data 57/757
# Testing data 58/757
# Testing data 59/757
# Testing data 60/757
# Testing data 61/757
# Testing data 62/757
# Testing data 63/757
# Testing data 64/757
# Testing data 65/757
# Testing data 66/757
# Testing data 67/757
# Testing data 68/757
# Testing data 69/757
# Testing data 70/757
# Testing data 71/757
# Testing data 72/757
# Testing data 73/757
# Testing data 74/757
# Testing data 75/757
# Testing data 76/757
# Testing data 77/757
# Testing data 78/757
# Testing data 79/757
# Testing data 80/757
# Testing data 81/757
# Testing data 82/757
# Testing data 83/757
# Testing data 84/757
# Testing data 85/757
# Testing data 86/757
# Testing data 87/757
# Testing data 88/757
# Testing data 89/757
# Testing data 90/757
# Testing data 91/757
# Testing data 92/757
# Testing data 93/757
# Testing data 94/757
# Testing data 95/757
# Testing data 96/757
# Testing data 97/757
# Testing data 98/757
# Testing data 99/757
# Testing data 100/757
# Testing data 101/757
# Testing data 102/757
# Testing data 103/757
# Testing data 104/757
# Testing data 105/757
# Testing data 106/757
# Testing data 107/757
# Testing data 108/757
# Testing data 109/757
# Testing data 110/757
# Testing data 111/757
# Testing data 112/757
# Testing data 113/757
# Testing data 114/757
# Testing data 115/757
# Testing data 116/757
# Testing data 117/757
# Testing data 118/757
# Testing data 119/757
# Testing data 120/757
# Testing data 121/757
# Testing data 122/757
# Testing data 123/757
# Testing data 124/757
# Testing data 125/757
# Testing data 126/757
# Testing data 127/757
# Testing data 128/757
# Testing data 129/757
# Testing data 130/757
# Testing data 131/757
# Testing data 132/757
# Testing data 133/757
# Testing data 134/757
# Testing data 135/757
# Testing data 136/757
# Testing data 137/757
# Testing data 138/757
# Testing data 139/757
# Testing data 140/757
# Testing data 141/757
# Testing data 142/757
# Testing data 143/757
# Testing data 144/757
# Testing data 145/757
# Testing data 146/757
# Testing data 147/757
# Testing data 148/757
# Testing data 149/757
# Testing data 150/757
# Testing data 151/757
# Testing data 152/757
# Testing data 153/757
# Testing data 154/757
# Testing data 155/757
# Testing data 156/757
# Testing data 157/757
# Testing data 158/757
# Testing data 159/757
# Testing data 160/757
# Testing data 161/757
# Testing data 162/757
# Testing data 163/757
# Testing data 164/757
# Testing data 165/757
# Testing data 166/757
# Testing data 167/757
# Testing data 168/757
# Testing data 169/757
# Testing data 170/757
# Testing data 171/757
# Testing data 172/757
# Testing data 173/757
# Testing data 174/757
# Testing data 175/757
# Testing data 176/757
# Testing data 177/757
# Testing data 178/757
# Testing data 179/757
# Testing data 180/757
# Testing data 181/757
# Testing data 182/757
# Testing data 183/757
# Testing data 184/757
# Testing data 185/757
# Testing data 186/757
# Testing data 187/757
# Testing data 188/757
# Testing data 189/757
# Testing data 190/757
# Testing data 191/757
# Testing data 192/757
# Testing data 193/757
# Testing data 194/757
# Testing data 195/757
# Testing data 196/757
# Testing data 197/757
# Testing data 198/757
# Testing data 199/757
# Testing data 200/757
# Testing data 201/757
# Testing data 202/757
# Testing data 203/757
# Testing data 204/757
# Testing data 205/757
# Testing data 206/757
# Testing data 207/757
# Testing data 208/757
# Testing data 209/757
# Testing data 210/757
# Testing data 211/757
# Testing data 212/757
# Testing data 213/757
# Testing data 214/757
# Testing data 215/757
# Testing data 216/757
# Testing data 217/757
# Testing data 218/757
# Testing data 219/757
# Testing data 220/757
# Testing data 221/757
# Testing data 222/757
# Testing data 223/757
# Testing data 224/757
# Testing data 225/757
# Testing data 226/757
# Testing data 227/757
# Testing data 228/757
# Testing data 229/757
# Testing data 230/757
# Testing data 231/757
# Testing data 232/757
# Testing data 233/757
# Testing data 234/757
# Testing data 235/757
# Testing data 236/757
# Testing data 237/757
# Testing data 238/757
# Testing data 239/757
# Testing data 240/757
# Testing data 241/757
# Testing data 242/757
# Testing data 243/757
# Testing data 244/757
# Testing data 245/757
# Testing data 246/757
# Testing data 247/757
# Testing data 248/757
# Testing data 249/757
# Testing data 250/757
# Testing data 251/757
# Testing data 252/757
# Testing data 253/757
# Testing data 254/757
# Testing data 255/757
# Testing data 256/757
# Testing data 257/757
# Testing data 258/757
# Testing data 259/757
# Testing data 260/757
# Testing data 261/757
# Testing data 262/757
# Testing data 263/757
# Testing data 264/757
# Testing data 265/757
# Testing data 266/757
# Testing data 267/757
# Testing data 268/757
# Testing data 269/757
# Testing data 270/757
# Testing data 271/757
# Testing data 272/757
# Testing data 273/757
# Testing data 274/757
# Testing data 275/757
# Testing data 276/757
# Testing data 277/757
# Testing data 278/757
# Testing data 279/757
# Testing data 280/757
# Testing data 281/757
# Testing data 282/757
# Testing data 283/757
# Testing data 284/757
# Testing data 285/757
# Testing data 286/757
# Testing data 287/757
# Testing data 288/757
# Testing data 289/757
# Testing data 290/757
# Testing data 291/757
# Testing data 292/757
# Testing data 293/757
# Testing data 294/757
# Testing data 295/757
# Testing data 296/757
# Testing data 297/757
# Testing data 298/757
# Testing data 299/757
# Testing data 300/757
# Testing data 301/757
# Testing data 302/757
# Testing data 303/757
# Testing data 304/757
# Testing data 305/757
# Testing data 306/757
# Testing data 307/757
# Testing data 308/757
# Testing data 309/757
# Testing data 310/757
# Testing data 311/757
# Testing data 312/757
# Testing data 313/757
# Testing data 314/757
# Testing data 315/757
# Testing data 316/757
# Testing data 317/757
# Testing data 318/757
# Testing data 319/757
# Testing data 320/757
# Testing data 321/757
# Testing data 322/757
# Testing data 323/757
# Testing data 324/757
# Testing data 325/757
# Testing data 326/757
# Testing data 327/757
# Testing data 328/757
# Testing data 329/757
# Testing data 330/757
# Testing data 331/757
# Testing data 332/757
# Testing data 333/757
# Testing data 334/757
# Testing data 335/757
# Testing data 336/757
# Testing data 337/757
# Testing data 338/757
# Testing data 339/757
# Testing data 340/757
# Testing data 341/757
# Testing data 342/757
# Testing data 343/757
# Testing data 344/757
# Testing data 345/757
# Testing data 346/757
# Testing data 347/757
# Testing data 348/757
# Testing data 349/757
# Testing data 350/757
# Testing data 351/757
# Testing data 352/757
# Testing data 353/757
# Testing data 354/757
# Testing data 355/757
# Testing data 356/757
# Testing data 357/757
# Testing data 358/757
# Testing data 359/757
# Testing data 360/757
# Testing data 361/757
# Testing data 362/757
# Testing data 363/757
# Testing data 364/757
# Testing data 365/757
# Testing data 366/757
# Testing data 367/757
# Testing data 368/757
# Testing data 369/757
# Testing data 370/757
# Testing data 371/757
# Testing data 372/757
# Testing data 373/757
# Testing data 374/757
# Testing data 375/757
# Testing data 376/757
# Testing data 377/757
# Testing data 378/757
# Testing data 379/757
# Testing data 380/757
# Testing data 381/757
# Testing data 382/757
# Testing data 383/757
# Testing data 384/757
# Testing data 385/757
# Testing data 386/757
# Testing data 387/757
# Testing data 388/757
# Testing data 389/757
# Testing data 390/757
# Testing data 391/757
# Testing data 392/757
# Testing data 393/757
# Testing data 394/757
# Testing data 395/757
# Testing data 396/757
# Testing data 397/757
# Testing data 398/757
# Testing data 399/757
# Testing data 400/757
# Testing data 401/757
# Testing data 402/757
# Testing data 403/757
# Testing data 404/757
# Testing data 405/757
# Testing data 406/757
# Testing data 407/757
# Testing data 408/757
# Testing data 409/757
# Testing data 410/757
# Testing data 411/757
# Testing data 412/757
# Testing data 413/757
# Testing data 414/757
# Testing data 415/757
# Testing data 416/757
# Testing data 417/757
# Testing data 418/757
# Testing data 419/757
# Testing data 420/757
# Testing data 421/757
# Testing data 422/757
# Testing data 423/757
# Testing data 424/757
# Testing data 425/757
# Testing data 426/757
# Testing data 427/757
# Testing data 428/757
# Testing data 429/757
# Testing data 430/757
# Testing data 431/757
# Testing data 432/757
# Testing data 433/757
# Testing data 434/757
# Testing data 435/757
# Testing data 436/757
# Testing data 437/757
# Testing data 438/757
# Testing data 439/757
# Testing data 440/757
# Testing data 441/757
# Testing data 442/757
# Testing data 443/757
# Testing data 444/757
# Testing data 445/757
# Testing data 446/757
# Testing data 447/757
# Testing data 448/757
# Testing data 449/757
# Testing data 450/757
# Testing data 451/757
# Testing data 452/757
# Testing data 453/757
# Testing data 454/757
# Testing data 455/757
# Testing data 456/757
# Testing data 457/757
# Testing data 458/757
# Testing data 459/757
# Testing data 460/757
# Testing data 461/757
# Testing data 462/757
# Testing data 463/757
# Testing data 464/757
# Testing data 465/757
# Testing data 466/757
# Testing data 467/757
# Testing data 468/757
# Testing data 469/757
# Testing data 470/757
# Testing data 471/757
# Testing data 472/757
# Testing data 473/757
# Testing data 474/757
# Testing data 475/757
# Testing data 476/757
# Testing data 477/757
# Testing data 478/757
# Testing data 479/757
# Testing data 480/757
# Testing data 481/757
# Testing data 482/757
# Testing data 483/757
# Testing data 484/757
# Testing data 485/757
# Testing data 486/757
# Testing data 487/757
# Testing data 488/757
# Testing data 489/757
# Testing data 490/757
# Testing data 491/757
# Testing data 492/757
# Testing data 493/757
# Testing data 494/757
# Testing data 495/757
# Testing data 496/757
# Testing data 497/757
# Testing data 498/757
# Testing data 499/757
# Testing data 500/757
# Testing data 501/757
# Testing data 502/757
# Testing data 503/757
# Testing data 504/757
# Testing data 505/757
# Testing data 506/757
# Testing data 507/757
# Testing data 508/757
# Testing data 509/757
# Testing data 510/757
# Testing data 511/757
# Testing data 512/757
# Testing data 513/757
# Testing data 514/757
# Testing data 515/757
# Testing data 516/757
# Testing data 517/757
# Testing data 518/757
# Testing data 519/757
# Testing data 520/757
# Testing data 521/757
# Testing data 522/757
# Testing data 523/757
# Testing data 524/757
# Testing data 525/757
# Testing data 526/757
# Testing data 527/757
# Testing data 528/757
# Testing data 529/757
# Testing data 530/757
# Testing data 531/757
# Testing data 532/757
# Testing data 533/757
# Testing data 534/757
# Testing data 535/757
# Testing data 536/757
# Testing data 537/757
# Testing data 538/757
# Testing data 539/757
# Testing data 540/757
# Testing data 541/757
# Testing data 542/757
# Testing data 543/757
# Testing data 544/757
# Testing data 545/757
# Testing data 546/757
# Testing data 547/757
# Testing data 548/757
# Testing data 549/757
# Testing data 550/757
# Testing data 551/757
# Testing data 552/757
# Testing data 553/757
# Testing data 554/757
# Testing data 555/757
# Testing data 556/757
# Testing data 557/757
# Testing data 558/757
# Testing data 559/757
# Testing data 560/757
# Testing data 561/757
# Testing data 562/757
# Testing data 563/757
# Testing data 564/757
# Testing data 565/757
# Testing data 566/757
# Testing data 567/757
# Testing data 568/757
# Testing data 569/757
# Testing data 570/757
# Testing data 571/757
# Testing data 572/757
# Testing data 573/757
# Testing data 574/757
# Testing data 575/757
# Testing data 576/757
# Testing data 577/757
# Testing data 578/757
# Testing data 579/757
# Testing data 580/757
# Testing data 581/757
# Testing data 582/757
# Testing data 583/757
# Testing data 584/757
# Testing data 585/757
# Testing data 586/757
# Testing data 587/757
# Testing data 588/757
# Testing data 589/757
# Testing data 590/757
# Testing data 591/757
# Testing data 592/757
# Testing data 593/757
# Testing data 594/757
# Testing data 595/757
# Testing data 596/757
# Testing data 597/757
# Testing data 598/757
# Testing data 599/757
# Testing data 600/757
# Testing data 601/757
# Testing data 602/757
# Testing data 603/757
# Testing data 604/757
# Testing data 605/757
# Testing data 606/757
# Testing data 607/757
# Testing data 608/757
# Testing data 609/757
# Testing data 610/757
# Testing data 611/757
# Testing data 612/757
# Testing data 613/757
# Testing data 614/757
# Testing data 615/757
# Testing data 616/757
# Testing data 617/757
# Testing data 618/757
# Testing data 619/757
# Testing data 620/757
# Testing data 621/757
# Testing data 622/757
# Testing data 623/757
# Testing data 624/757
# Testing data 625/757
# Testing data 626/757
# Testing data 627/757
# Testing data 628/757
# Testing data 629/757
# Testing data 630/757
# Testing data 631/757
# Testing data 632/757
# Testing data 633/757
# Testing data 634/757
# Testing data 635/757
# Testing data 636/757
# Testing data 637/757
# Testing data 638/757
# Testing data 639/757
# Testing data 640/757
# Testing data 641/757
# Testing data 642/757
# Testing data 643/757
# Testing data 644/757
# Testing data 645/757
# Testing data 646/757
# Testing data 647/757
# Testing data 648/757
# Testing data 649/757
# Testing data 650/757
# Testing data 651/757
# Testing data 652/757
# Testing data 653/757
# Testing data 654/757
# Testing data 655/757
# Testing data 656/757
# Testing data 657/757
# Testing data 658/757
# Testing data 659/757
# Testing data 660/757
# Testing data 661/757
# Testing data 662/757
# Testing data 663/757
# Testing data 664/757
# Testing data 665/757
# Testing data 666/757
# Testing data 667/757
# Testing data 668/757
# Testing data 669/757
# Testing data 670/757
# Testing data 671/757
# Testing data 672/757
# Testing data 673/757
# Testing data 674/757
# Testing data 675/757
# Testing data 676/757
# Testing data 677/757
# Testing data 678/757
# Testing data 679/757
# Testing data 680/757
# Testing data 681/757
# Testing data 682/757
# Testing data 683/757
# Testing data 684/757
# Testing data 685/757
# Testing data 686/757
# Testing data 687/757
# Testing data 688/757
# Testing data 689/757
# Testing data 690/757
# Testing data 691/757
# Testing data 692/757
# Testing data 693/757
# Testing data 694/757
# Testing data 695/757
# Testing data 696/757
# Testing data 697/757
# Testing data 698/757
# Testing data 699/757
# Testing data 700/757
# Testing data 701/757
# Testing data 702/757
# Testing data 703/757
# Testing data 704/757
# Testing data 705/757
# Testing data 706/757
# Testing data 707/757
# Testing data 708/757
# Testing data 709/757
# Testing data 710/757
# Testing data 711/757
# Testing data 712/757
# Testing data 713/757
# Testing data 714/757
# Testing data 715/757
# Testing data 716/757
# Testing data 717/757
# Testing data 718/757
# Testing data 719/757
# Testing data 720/757
# Testing data 721/757
# Testing data 722/757
# Testing data 723/757
# Testing data 724/757
# Testing data 725/757
# Testing data 726/757
# Testing data 727/757
# Testing data 728/757
# Testing data 729/757
# Testing data 730/757
# Testing data 731/757
# Testing data 732/757
# Testing data 733/757
# Testing data 734/757
# Testing data 735/757
# Testing data 736/757
# Testing data 737/757
# Testing data 738/757
# Testing data 739/757
# Testing data 740/757
# Testing data 741/757
# Testing data 742/757
# Testing data 743/757
# Testing data 744/757
# Testing data 745/757
# Testing data 746/757
# Testing data 747/757
# Testing data 748/757
# Testing data 749/757
# Testing data 750/757
# Testing data 751/757
# Testing data 752/757
# Testing data 753/757
# Testing data 754/757
# Testing data 755/757
# Testing data 756/757
# Testing data 757/757
# Runtime: 1387.138130903244

# %% [markdown]
# # Preprocess Data, Create Labels, and Create Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
def load_keypoint_features(base_directory, sequences, labels):
    for action_name in os.listdir(base_directory):
        action_path = os.path.join(base_directory, action_name)
        # Check if it's actually a directory
        if os.path.isdir(action_path):
            # Loop through each video directory within the action directory
            for video_name in os.listdir(action_path):
                window = []
                video_path = os.path.join(action_path, video_name)
                # Check if the current path is a directory and not empty
                if os.path.isdir(video_path) and os.listdir(video_path):
                    # For each video, go through load the extracted feature data at every frame
                    for frame in os.listdir(video_path):
                        if frame.endswith('.npy'):
                            res = np.load(os.path.join(video_path, frame))
                            window.append(res)
                        else:
                            print(f'Skipped file {frame}')
                    sequences.append(window)
                    labels.append(label_map[action_name])

    padded_sequences = pad_sequences(sequences, padding='post', dtype='float32')
    categorical_labels = to_categorical(labels).astype(int)
    return padded_sequences, categorical_labels

# %%
# NOTE: Sequences represent extracted features (x-data) and labels represent label/category (y-data)
train_sequences, train_labels = [], []
test_sequences, test_labels = [], []

train_base_directory = os.path.join(DATA_PATH, 'Train')
test_base_directory = os.path.join(DATA_PATH, 'Test')
X_train, y_train = load_keypoint_features(train_base_directory, train_sequences, train_labels)
X_test, y_test = load_keypoint_features(test_base_directory, test_sequences, test_labels)

# %%
print(X_test.shape)
print(y_test.shape)
print(X_train.shape)
print(y_train.shape)
# Out:
# (522, 168, 1662)
# (522, 100)
# (2813, 270, 1662)
# (2813, 100)

# %% [markdown]
# # Build and Train the Nueural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Masking, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam
# TODO: Decide if I want to remove the logs for final submission
from tensorflow.keras.callbacks import TensorBoard

# %%
# TODO: Remove this for final submission?
# Set up the log directory for TensorBoard
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
# Define the model architecture
model = Sequential()
model.add(Masking(mask_value=0., input_shape=(None, 1662)))
model.add(Bidirectional(LSTM(64, return_sequences=True, activation='tanh')))
model.add(Dropout(0.5))
model.add(LSTM(128, return_sequences=True, activation='tanh'))
model.add(Dropout(0.5))
model.add(LSTM(64, return_sequences=False, activation='tanh'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(len(actions), activation='softmax'))

# %%
#optimizer = Adam(learning_rate=0.01, clipnorm=1.0)
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
#model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
# Train the model on training data
# TODO: Figure out sweet in training for epochs GET GRAPHS SO I CAN JUSTIFY IN REPORT
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 56s 585ms/step - categorical_accuracy: 0.0175 - loss: 4.5950
# Epoch 2/2000
# 31/88 ━━━━━━━━━━━━━━━━━━━━ 38s 672ms/step - categorical_accuracy: 0.0131 - loss: 4.5797
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[300], line 3
#       1 # Train the model on training data
#       2 # TODO: Figure out sweet in training for epochs GET GRAPHS SO I CAN JUSTIFY IN REPORT
# ----> 3 model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Save and Load Model TODO: Remove this Section for Final Submission

# %%
# TODO: Figure out submission format and delete, move, or change load_weights correspondingly
# Save the model
model.save('CustomData_375Epochs.keras')
#model.load_weights('action.keras')

# %% [markdown]
# # Evaluate Model Performance with Testing Data

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
print(X_test.shape)
# Out:
# (522, 168, 1662)

# %%
# Make predictions on the testing data
yhat = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step

# %%
# Convert the predictions from their one-hot encoded (e.g. [1,0,0], [0,1,0]) prediction to corresponding categorical label (e.g. 0, 1, 2)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
# Use these metrics to evaluate performance of model
print(multilabel_confusion_matrix(ytrue, yhat))
print(accuracy_score(ytrue, yhat))
# Out:
# [[[3 1]
#   [1 0]]
#
#  [[3 1]
#   [0 1]]
#
#  [[2 0]
#   [1 2]]]
# 0.6

# %% [markdown]
# # Test the Model in Real Time

# %%
from scipy import stats

# %%
# Delclare variables that are used for making detections
sequence = []
sentence = []
predictions = []
threshold = 0.5

# Set up videocapture and loop through frames
cap = cv2.VideoCapture(0) #Device value 0 should correspond to the webcam
# Check if the camera opened successfully
if not cap.isOpened():
    print("Error: Could not open video capture device.")
    exit()

# Set the mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    try:
        while cap.isOpened():
            ret, frame = cap.read() # Capture the return value and frame at each point in camera
            # Make sure that the frame is read correctly
            if not ret:
                print("Can't receive frame (stream end?). Exiting ...")
                break
    
            # Make detections
            image, results = mediapipe_detection(frame, holistic)

            # Draw landmarks on frame
            draw_styled_landmarks(image, results)

            # Prediction logic keeps the most recent 30 frames for each prediction
            keypoints = extract_keypoints(results)
            sequence.append(keypoints)
            sequence = sequence[-30:]

            # We only want to start making predictions once we have 30 frames of data to use
            if len(sequence) == 30:
                res = model.predict(np.expand_dims(sequence, axis=0))[0] # Need to use expand_dims because our model is expecting a row indicating number of sequences
                predictions.append(np.argmax(res))

                # Visualization Logic
                # Only make predictions if it has been confident in that prediction for 10 slides in a row
                if np.unique(predictions[-10:])[0] == np.argmax(res):
                    # We only want to make a prediction if the model is confident in that sign
                    if res[np.argmax(res)] > threshold:
                        if len(sentence) > 0:
                            # We don't want to add an action to the sentence until it is a new action (not double counting actions)
                            if actions[np.argmax(res)] != sentence[-1]:
                                sentence.append(actions[np.argmax(res)])
                        else:
                            sentence.append(actions[np.argmax(res)])
    
                # Make sure that we do not end with giant sentences
                if len(sentence) > 5:
                    sentence = sentence[-5:]

            # Render rectangle around prediction
            cv2.rectangle(image, (0,0), (2000, 40), (500, 117, 16), -1)
            cv2.putText(image, ' '.join(sentence), (3,30),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            cv2.imshow('OpenCV Feed', image) # Show the current frame to the user and names the feed "OpenCV Feed"
        
            # Break out of the capture feed gracefully if the q key is pressed
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break     
    finally:
        cap.release()
        cv2.destroyAllWindows()
        # There is a known bug on Mac where destroyAllWindows doesn't work unless a certain amount of time is spent waiting after
        for i in range (1,5):
            cv2.waitKey(1)
